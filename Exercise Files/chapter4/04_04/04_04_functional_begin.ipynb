# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import sys, os, math, random, functools

import numpy as np

import matplotlib
import matplotlib.pyplot as pp
import matplotlib.animation as anim

# %matplotlib inline

from IPython.display import display, HTML

# %% [markdown]
# ### Code from previous videos (enhanced)

# %%
from turtle import Turtle, Terrarium

# %% [markdown]
# ## Making fractals with functional Python

# %%
def snowflake(turtle,dist,level):
    for i in range(3):
        drawkoch(turtle,dist,level)
        turtle.right(120)

def drawkoch(turtle,distance,level):
    if level == 0:
        turtle.forward(distance)
    else:
        drawkoch(turtle,distance/3,level-1)
        turtle.left(60)
        drawkoch(turtle,distance/3,level-1)
        turtle.left(-120)
        drawkoch(turtle,distance/3,level-1)
        turtle.left(60)
        drawkoch(turtle,distance/3,level-1)

# %%
with Terrarium(figsize = 10) as t:
    drawkoch(Turtle(t),100,1)

# %%
with Terrarium() as t:
    drawkoch(Turtle(t),100,2)

# %%
with Terrarium(animate=True) as t:
    drawkoch(Turtle(t),100,3)
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
with Terrarium(animate=False) as t:
    drawkoch(Turtle(t),100,4)

# %%
with Terrarium(figsize = 20, animate= True) as t:
    t1 = Turtle(t)
    
    def flake():
        snowflake(t1, 30, 3)
        
    def left():
        t1.left(60)

    for f in [flake, left] * 6:
        f()
# Out:
# <video width="1440" height="1440" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
def over(a,b):
    return a/b

# %%
inverse = functools.partial(over, 1)
half = functools.partial(over, b=2)

# %%
inverse(2)
# Out:
# 0.5

# %%
half(3)
# Out:
# 1.5

# %%
inverse
# Out:
# functools.partial(<function over at 0x0000021A9FF28730>, 1)

# %%
def F(dist):
    return functools.partial(Turtle.forward, distance = dist)

def L(ang):
    return functools.partial(Turtle.left, angle=ang)

# %%
f100 = F(100)

with Terrarium() as t:
    f100(Turtle(t))

# %%
def funckoch(steps):
    newsteps=[]
    
    for step in steps:
        if step.func is Turtle.forward:
            F3 = F(step.keywords['distance']/3)
            newsteps += [F3, L(60), F3, L(-120), F3, L(60), F3]
        else:
            newsteps += [step]
            
    return newsteps

# %%
step0 = [F(100)]

# %%
funckoch(step0)
# Out:
# [functools.partial(<function Turtle.forward at 0x0000021A9FF17730>, distance=33.333333333333336),
#  functools.partial(<function Turtle.left at 0x0000021A9FF17840>, angle=60),
#  functools.partial(<function Turtle.forward at 0x0000021A9FF17730>, distance=33.333333333333336),
#  functools.partial(<function Turtle.left at 0x0000021A9FF17840>, angle=-120),
#  functools.partial(<function Turtle.forward at 0x0000021A9FF17730>, distance=33.333333333333336),
#  functools.partial(<function Turtle.left at 0x0000021A9FF17840>, angle=60),
#  functools.partial(<function Turtle.forward at 0x0000021A9FF17730>, distance=33.333333333333336)]

# %%
with Terrarium() as t:
    t1 = Turtle(t)
    
    for f in funckoch(funckoch(funckoch(step0))):
        f(t1)

# %%
def iterated(f,n):
    def iterf(arg):
        ret = arg
        for i in range(n):
            ret = f(ret)
        return ret

    return iterf

# %%
def turtle_map(self,steps):
    for step in steps:
        step(self)
        
Turtle.map = turtle_map

# %%
with Terrarium() as t:
    Turtle(t).map(iterated(funckoch,5)(step0))

# %%
triangle = [F(100),L(-120),F(100),L(-120),F(100)]

# %%
with Terrarium(animate=True,duration=2) as t:
    Turtle(t).map(iterated(funckoch,5)(triangle))
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
# Out:
# 59
